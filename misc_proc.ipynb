# %%
from scipy import misc
import matplotlib.pyplot as plt

# %%
im = misc.imread('1.jpg')
print(im.dtype)
print(im.size)
print(im.shape)
misc.imsave('misc1.png',im)
plt.imshow(im)
plt.show()
print(im)
# Out:
# F:\Anaconda\envs\python35\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.
# uint8
# 786816
# (384, 683, 3)
# F:\Anaconda\envs\python35\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   """
# [[[ 30  32  71]
#   [ 30  32  71]
#   [ 30  32  71]
#   ...,
#   [ 31  33  71]
#   [ 31  34  69]
#   [ 31  34  69]]
#
#  [[ 31  33  72]
#   [ 31  33  72]
#   [ 30  32  71]
#   ...,
#   [ 31  33  71]
#   [ 31  34  69]
#   [ 31  34  69]]
#
#  [[ 30  32  71]
#   [ 30  32  71]
#   [ 30  32  71]
#   ...,
#   [ 31  33  71]
#   [ 31  34  69]
#   [ 31  34  69]]
#
#  ...,
#  [[107 147 172]
#   [162 204 228]
#   [168 210 232]
#   ...,
#   [ 29  47  85]
#   [ 42  60 100]
#   [ 35  53  93]]
#
#  [[146 192 215]
#   [162 208 231]
#   [171 217 240]
#   ...,
#   [ 43  55  93]
#   [ 31  38  80]
#   [ 43  50  92]]
#
#  [[152 203 224]
#   [167 218 239]
#   [165 213 235]
#   ...,
#   [ 38  43  81]
#   [ 40  39  79]
#   [ 47  46  86]]]

# %%
import imageio
im2 = imageio.imread('1.jpg')
print(im2.dtype)
print(im2.size)
print(im2.shape)
plt.imshow(im)
plt.show()
print(im2)
imageio.imsave('imageio.png',im2)
# Out:
# uint8
# 786816
# (384, 683, 3)
# [[[ 30  32  71]
#   [ 30  32  71]
#   [ 30  32  71]
#   ...,
#   [ 31  33  71]
#   [ 31  34  69]
#   [ 31  34  69]]
#
#  [[ 31  33  72]
#   [ 31  33  72]
#   [ 30  32  71]
#   ...,
#   [ 31  33  71]
#   [ 31  34  69]
#   [ 31  34  69]]
#
#  [[ 30  32  71]
#   [ 30  32  71]
#   [ 30  32  71]
#   ...,
#   [ 31  33  71]
#   [ 31  34  69]
#   [ 31  34  69]]
#
#  ...,
#  [[107 147 172]
#   [162 204 228]
#   [168 210 232]
#   ...,
#   [ 29  47  85]
#   [ 42  60 100]
#   [ 35  53  93]]
#
#  [[146 192 215]
#   [162 208 231]
#   [171 217 240]
#   ...,
#   [ 43  55  93]
#   [ 31  38  80]
#   [ 43  50  92]]
#
#  [[152 203 224]
#   [167 218 239]
#   [165 213 235]
#   ...,
#   [ 38  43  81]
#   [ 40  39  79]
#   [ 47  46  86]]]
